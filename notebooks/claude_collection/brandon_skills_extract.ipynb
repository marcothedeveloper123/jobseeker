# %%
from llama_index import PromptTemplate
from llama_index.llms import Bedrock, ChatMessage
from llama_index.program import LLMTextCompletionProgram
from llama_index.output_parsers import PydanticOutputParser
from pydantic import BaseModel, Field
from typing import List
import pandas as pd

# %%
# Need to have AWS creddentials loaded into environment
# This could be previously done in ~/.aws/credentials
bedrock = Bedrock(model="anthropic.claude-v2", max_tokens=8000)

# %%
# Load the raw data
job_df = pd.read_csv("../../data/bronze/apify/indeed/dataset_indeed-scraper_2023-10-23_07-07-15.csv")
descriptions = job_df['description'].to_list()

# %%
# Create the pydantic class to output into

class Skill(BaseModel):
    name: str
    reference_text: str

class Job(BaseModel):
    skills: List[Skill]

# Create the program to parse each description
job_program = LLMTextCompletionProgram.from_defaults(
    output_parser=PydanticOutputParser(Job),
    llm=bedrock,
    prompt_template_str="Extract the Job skills, with the reference text to that skill, from the following description: {description}",
    verbose=True
)

# %%
test_output = job_program(description=descriptions[0])

# %%
for skill in test_output.skills:
    if skill.reference_text in descriptions[0]:
        print(skill)
    else:
        print(skill.name, "is not in the description")
# Out:
# name='ETL' reference_text='Design, develop, and maintain ETL pipelines on Google Cloud Platform (GCP) to ensure efficient data extraction, transformation, and loading processes.'
# name='Google Cloud Platform' reference_text='Proven experience in designing and developing ETL pipelines on Google Cloud Platform (GCP).'

# %%
# Test out some of the New data
marco_csvs = pd.read_csv("../../data/jobs_Head_of_Product_-_European_Union_-_Remote_-_LinkedIn.csv")
descriptions = marco_csvs['job_description'].to_list()
print(descriptions[0])
# Out:
# About the job
#
#
# About RevolutPeople deserve more from their money. More visibility, more control, more freedom. And since 2015, Revolut has been on a mission to deliver just that. With an arsenal of aweso﻿me products that span spending, saving, travel, transfers, investing, exchanging and more, our super app has helped 35+ million customers get more from their money. And we're not done yet.  As we continue our lightning-fast growth,‌ two things are essential to continuing our success: our people and our culture. We've been officially certified as a Great Place to Work™ in recognition of our outstanding employee experience! So far, we have 7,500+﻿ people working around the world, from our great offices or remotely, on our mission. And we're looking for more. We want brilliant people that love building great products, love redefining success, and love turning the complexity of a chaotic world into the simplicity of a beautiful solution.About The RoleOn the Revolut rocket ship, there aren't many teams more important than Product. To put it simply: there’s no lift off without these guys. Frankly, there’s no rocket. Every one of our award-winning features started here and all our future ones will too 🏆The team’s scope is wide, leading on the integration of engineering, data science, operations, and design. But when it comes to our vision of reinventing financial services, they’re laser focused 🔫Product Owners at Revolut hold the helm 🚢 If you join the Dream Team, you’ll have sole responsibility over the roadmap of your product. Total ownership. The people, the profit, the loss, all in your hands. It’s fast paced. Very much so. But if you can manage all that - and bring with it a bottle full of entrepreneurial passion - then you’re probably the captain we’re looking for ⚓To find out more about our recent launch of Rev10 and hear from some of the people you will be working with, check out this video!What You’ll Be Doing Completely owning and building our Crypto Exchange product, increasing the number of tokens tradable in the application and providing the tools retail users expect from exchangesSetting your team's goals, success metrics, and roadmap to align with Revolut’s mission and drive maximum impact based on data analysis, market research, and company strategyWorking with our Core Crypto team to expand and improve our suite of crypto products, including deposits, withdrawals, and staking, making them more accessible for our retail usersWorking closely with Design and UX Research to define the customer journey and create an amazing user experienceLiaising with Engineering to ensure effective delivery of the productCollaborating with other stakeholders, such as Product Marketing, Legal, and Product Strategy
# What You'll Need 2-3 years of experience building a crypto exchange platform2+ years of proven success building the core functionality of trading products1+ years of experience in managing people (Product Owners at Revolut directly manage Engineering, Operations, and Design)Experience managing a team of product owners and delivering successful products from 0-1A STEM backgroundOutstanding verbal and written communication skillsAn eye for great UX/UI and a good understanding of design best practicesAn understanding of technical backend with integrations and APIsHigh analytical acumen along with strong business sense that guides ROI based prioritisationExperience formulating and driving a focused product vision, owning the narrative with leadership, users, and partnersA bias to action and bootstrapping major projects, never hesitating to roll up your sleeves and be hands onA readiness to provide insight and deliver measurable results for sophisticated products under ambiguous situations in a fast-paced environment
# Nice to have Experience in Trading/Quant
# Building a global financial super app isn’t enough. Our Revoluters are a priority, and that’s why in 2021 we launched our inaugural D&I Framework, designed to help us thrive and grow everyday. We're not just doing this because it's the right thing to do. We’re doing it because we know that seeking out diverse talent and creating an inclusive workplace is the way to create exceptional, innovative products and services for our customers. That’s why we encourage applications from people with diverse backgrounds and experiences to join this multicultural, hard-working team.Refer to our Data Privacy Statement for Candidates: https://www.revolut.com/legal/data-privacy-for-candidates for details on our data handling practices during your application.

# %%
marco_csvs
# Out:
#                                             job_title  \
# 0                   Head of Product (Crypto Exchange)
# 1                             Head of Product (w/m/d)
# 2                            Head of Product - Voluum
# 3                                Senior Product Owner
# 4                                CPO-B2C- Remoto 100%
# 5                             Head of Product (f/d/m)
# 6                               Head of Slots Product
# 7                  Senior Product Owner (all genders)
# 8     Domain Owner (Head of Product) - Web Experience
# 9                                       Product Owner
# 10                     VP of Product (m/f/d) - Remote
# 11                               Senior Product Owner
# 12                                      Product Owner
# 13            Senior Product Owner(ka) pre Dátový tím
# 14  Technical Product Owner, Trilogy (Remote) - $1...
# 15         Director of Product - Application Platform
# 16                         Head of Product - Zeropark
# 17              Product Owner Digitalisierung (m/w/d)
# 18                                    Head of Product
# 19                               Senior Product Owner
# 20                        Product Operations Director
# 21                       Product Owner Sustainability
# 22                        Head of Product Engineering
# 23                          Product Owner (Iris Team)
# 24  Product Content Owner - InfoSec & Privacy Expe...
#
#                                          company_name  \
# 0                                             Revolut
# 1                                          ASI Reisen
# 2                                       Team Internet
# 3                      ARRISE powering Pragmatic Play
# 4                                        Michael Page
# 5   Kooku Recruiting GmbH - Interim Recruiting & R...
# 6                                        Huuuge Games
# 7                                PŸUR | Tele Columbus
# 8                                       METRO.digital
# 9                                              Luxoft
# 10                                           Sastrify
# 11                                   Zurich Insurance
# 12                                     Luxoft Romania
# 13                                            GymBeam
# 14                                          Crossover
# 15                                           PandaDoc
# 16                                      Team Internet
# 17                 operational services GmbH & Co. KG
# 18                                               Ocho
# 19                                           Devoteam
# 20                                             Copado
# 21                                 B2X Care Solutions
# 22                                            Revolut
# 23                                            Semrush
# 24                                          DataGuard
#
#                                           location  \
# 0                                 Ireland (Remote)
# 1                          Tyrol, Austria (Remote)
# 2             Cracow, Małopolskie, Poland (Remote)
# 3                          European Union (Remote)
# 4      Madrid, Community of Madrid, Spain (Remote)
# 5                                 Germany (Remote)
# 6                                  Poland (Remote)
# 7                                 Germany (Remote)
# 8                                 Romania (Remote)
# 9                                 Romania (Remote)
# 10                Berlin, Berlin, Germany (Remote)
# 11                               Slovakia (Remote)
# 12                     Bucharest, Romania (Remote)
# 13                               Slovakia (Remote)
# 14  Amsterdam, North Holland, Netherlands (Remote)
# 15                                 Poland (Remote)
# 16            Cracow, Małopolskie, Poland (Remote)
# 17                                Germany (Remote)
# 18                 County Dublin, Ireland (Remote)
# 19               Lisboa, Lisbon, Portugal (Remote)
# 20     Madrid, Community of Madrid, Spain (Remote)
# 21                         European Union (Remote)
# 22                                  Spain (Remote)
# 23                                Czechia (Remote)
# 24                                Germany (Remote)
#
#                                              job_link      job_id  \
# 0   https://www.linkedin.com/jobs/view/3736226364/...  3736226364
# 1   https://www.linkedin.com/jobs/view/3759081878/...  3759081878
# 2   https://www.linkedin.com/jobs/view/3728862329/...  3728862329
# 3   https://www.linkedin.com/jobs/view/3721306074/...  3721306074
# 4   https://www.linkedin.com/jobs/view/3748364702/...  3748364702
# 5   https://www.linkedin.com/jobs/view/3774497203/...  3774497203
# 6   https://www.linkedin.com/jobs/view/3713712362/...  3713712362
# 7   https://www.linkedin.com/jobs/view/3744872668/...  3744872668
# 8   https://www.linkedin.com/jobs/view/3755475139/...  3755475139
# 9   https://www.linkedin.com/jobs/view/3777991849/...  3777991849
# 10  https://www.linkedin.com/jobs/view/3762575445/...  3762575445
# 11  https://www.linkedin.com/jobs/view/3760870051/...  3760870051
# 12  https://www.linkedin.com/jobs/view/3778217641/...  3778217641
# 13  https://www.linkedin.com/jobs/view/3771891067/...  3771891067
# 14  https://www.linkedin.com/jobs/view/3778778064/...  3778778064
# 15  https://www.linkedin.com/jobs/view/3738553031/...  3738553031
# 16  https://www.linkedin.com/jobs/view/3732292970/...  3732292970
# 17  https://www.linkedin.com/jobs/view/3761866977/...  3761866977
# 18  https://www.linkedin.com/jobs/view/3765625443/...  3765625443
# 19  https://www.linkedin.com/jobs/view/3772657470/...  3772657470
# 20  https://www.linkedin.com/jobs/view/3773537782/...  3773537782
# 21  https://www.linkedin.com/jobs/view/3773508468/...  3773508468
# 22  https://www.linkedin.com/jobs/view/3440830299/...  3440830299
# 23  https://www.linkedin.com/jobs/view/3767390611/...  3767390611
# 24  https://www.linkedin.com/jobs/view/3767456089/...  3767456089
#
#                                       job_description
# 0   About the job\n            \n \nAbout RevolutP...
# 1   About the job\n            \n \nASI Reisen ist...
# 2   About the job\n            \n \nDepartment: Pr...
# 3   About the job\n            \n \nDescriptionAbo...
# 4   About the job\n            \n \nProyecto ambic...
# 5   About the job\n            \n \nAbout our Clie...
# 6   About the job\n            \n \nIntroductionSt...
# 7   About the job\n            \n \nÜber Tele Colu...
# 8   About the job\n            \n \nAbout us: Pass...
# 9   About the job\n            \n \nProject Descri...
# 10  About the job\n            \n \nWe at Sastrify...
# 11  About the job\n            \n \nOur opportunit...
# 12  About the job\n            \n \nProject Descri...
# 13  About the job\n            \n \nHľadáme talent...
# 14  About the job\n            \n \nCrossover is t...
# 15  About the job\n            \n \nIn This Role, ...
# 16  About the job\n            \n \nDepartment: Pr...
# 17  About the job\n            \n \nAls Product Ow...
# 18  About the job\n            \n \nWho is the Cli...
# 19  About the job\n            \n \nCompany Descri...
# 20  About the job\n            \n \nAbout Copado:C...
# 21  About the job\n            \n \nThe RoleAs a P...
# 22  About the job\n            \n \nAbout RevolutP...
# 23  About the job\n            \n \nHi there!This ...
# 24  About the job\n            \n \nIntroDu bist e...

# %%
marco_test_output = job_program(description=descriptions[0])
print(marco_test_output.skills)
# Out:
# [Skill(name='Crypto Exchange Product Management', reference_text='Completely owning and building our Crypto Exchange product, increasing the number of tokens tradable in the application and providing the tools retail users expect from exchanges'), Skill(name='Team Leadership', reference_text="Setting your team's goals, success metrics, and roadmap to align with Revolut’s mission and drive maximum impact based on data analysis, market research, and company strategy"), Skill(name='Crypto Product Expansion', reference_text='Working with our Core Crypto team to expand and improve our suite of crypto products, including deposits, withdrawals, and staking, making them more accessible for our retail users'), Skill(name='User Experience Design', reference_text='Working closely with Design and UX Research to define the customer journey and create an amazing user experience'), Skill(name='Engineering Collaboration', reference_text='Liaising with Engineering to ensure effective delivery of the product'), Skill(name='Stakeholder Collaboration', reference_text='Collaborating with other stakeholders, such as Product Marketing, Legal, and Product Strategy')]

# %%
for skill in marco_test_output.skills:
    if skill.reference_text in descriptions[0]:
        print(skill)
    else:
        print(skill.name, "is not in the description")
# Out:
# name='Crypto Exchange Product Management' reference_text='Completely owning and building our Crypto Exchange product, increasing the number of tokens tradable in the application and providing the tools retail users expect from exchanges'
# name='Team Leadership' reference_text="Setting your team's goals, success metrics, and roadmap to align with Revolut’s mission and drive maximum impact based on data analysis, market research, and company strategy"
# name='Crypto Product Expansion' reference_text='Working with our Core Crypto team to expand and improve our suite of crypto products, including deposits, withdrawals, and staking, making them more accessible for our retail users'
# name='User Experience Design' reference_text='Working closely with Design and UX Research to define the customer journey and create an amazing user experience'
# name='Engineering Collaboration' reference_text='Liaising with Engineering to ensure effective delivery of the product'
# name='Stakeholder Collaboration' reference_text='Collaborating with other stakeholders, such as Product Marketing, Legal, and Product Strategy'

# %%
skills_in_descriptions = []
failed = []
for index, description in enumerate(descriptions):
    try:
        output = job_program(description=description)
        index_description = {
            "index": index,
            "description": description,
            "skills": output
        }
        skills_in_descriptions.append(index_description)
        print(f"Completed {index}")
    except Exception as e:
        print(f"Error on {index} - {e}")
        index_description = {
            "index": index,
            "description": description
        }
        failed.append(index_description)
        continue

# %%
# Store the data that was just generated
# Made a mistake and need to dump the Job model
new_skills_dicts = []
for skill in skills_in_descriptions:
    new_dict = {
        "index": skill["index"],
        "description": skill["description"],
        "skills": [skill["skills"].model_dump()]
    }
    new_skills_dicts.append(new_dict)

# %%
# Assuming new_skills_dicts is a list of dictionaries containing the data
df = pd.DataFrame(new_skills_dicts)

# %%
df.to_json("skills_json_from_df.json", orient="records")

# %%
# Load the json file into a dataframe
# Use this to check the output
df = pd.read_json("skills_json_from_df.json")

# %%
skills = df['skills'].to_list()
descriptions_from_df = df['description'].to_list()

# %%
for index, skill in enumerate(skills):
    print(f"Job Index: {index}")
    print(descriptions_from_df[index])
    for skill_item in skill:
        for specific_skill in skill_item['skills']:
            print(specific_skill)
    print()
# Out:
# Job Index: 0
# About the job
#
#
# About RevolutPeople deserve more from their money. More visibility, more control, more freedom. And since 2015, Revolut has been on a mission to deliver just that. With an arsenal of aweso﻿me products that span spending, saving, travel, transfers, investing, exchanging and more, our super app has helped 35+ million customers get more from their money. And we're not done yet.  As we continue our lightning-fast growth,‌ two things are essential to continuing our success: our people and our culture. We've been officially certified as a Great Place to Work™ in recognition of our outstanding employee experience! So far, we have 7,500+﻿ people working around the world, from our great offices or remotely, on our mission. And we're looking for more. We want brilliant people that love building great products, love redefining success, and love turning the complexity of a chaotic world into the simplicity of a beautiful solution.About The RoleOn the Revolut rocket ship, there aren't many teams more important than Product. To put it simply: there’s no lift off without these guys. Frankly, there’s no rocket. Every one of our award-winning features started here and all our future ones will too 🏆The team’s scope is wide, leading on the integration of engineering, data science, operations, and design. But when it comes to our vision of reinventing financial services, they’re laser focused 🔫Product Owners at Revolut hold the helm 🚢 If you join the Dream Team, you’ll have sole responsibility over the roadmap of your product. Total ownership. The people, the profit, the loss, all in your hands. It’s fast paced. Very much so. But if you can manage all that - and bring with it a bottle full of entrepreneurial passion - then you’re probably the captain we’re looking for ⚓To find out more about our recent launch of Rev10 and hear from some of the people you will be working with, check out this video!What You’ll Be Doing Completely owning and building our Crypto Exchange product, increasing the number of tokens tradable in the application and providing the tools retail users expect from exchangesSetting your team's goals, success metrics, and roadmap to align with Revolut’s mission and drive maximum impact based on data analysis, market research, and company strategyWorking with our Core Crypto team to expand and improve our suite of crypto products, including deposits, withdrawals, and staking, making them more accessible for our retail usersWorking closely with Design and UX Research to define the customer journey and create an amazing user experienceLiaising with Engineering to ensure effective delivery of the productCollaborating with other stakeholders, such as Product Marketing, Legal, and Product Strategy
# What You'll Need 2-3 years of experience building a crypto exchange platform2+ years of proven success building the core functionality of trading products1+ years of experience in managing people (Product Owners at Revolut directly manage Engineering, Operations, and Design)Experience managing a team of product owners and delivering successful products from 0-1A STEM backgroundOutstanding verbal and written communication skillsAn eye for great UX/UI and a good understanding of design best practicesAn understanding of technical backend with integrations and APIsHigh analytical acumen along with strong business sense that guides ROI based prioritisationExperience formulating and driving a focused product vision, owning the narrative with leadership, users, and partnersA bias to action and bootstrapping major projects, never hesitating to roll up your sleeves and be hands onA readiness to provide insight and deliver measurable results for sophisticated products under ambiguous situations in a fast-paced environment
# Nice to have Experience in Trading/Quant
# Building a global financial super app isn’t enough. Our Revoluters are a priority, and that’s why in 2021 we launched our inaugural D&I Framework, designed to help us thrive and grow everyday. We're not just doing this because it's the right thing to do. We’re doing it because we know that seeking out diverse talent and creating an inclusive workplace is the way to create exceptional, innovative products and services for our customers. That’s why we encourage applications from people with diverse backgrounds and experiences to join this multicultural, hard-working team.Refer to our Data Privacy Statement for Candidates: https://www.revolut.com/legal/data-privacy-for-candidates for details on our data handling practices during your application.
# {'skills': [{'name': 'Crypto Exchange Product Management', 'reference_text': 'Completely owning and building our Crypto Exchange product, increasing the number of tokens tradable in the application and providing the tools retail users expect from exchanges'}, {'name': 'Roadmapping', 'reference_text': "Setting your team's goals, success metrics, and roadmap to align with Revolut’s mission and drive maximum impact based on data analysis, market research, and company strategy"}, {'name': 'Crypto Product Development', 'reference_text': 'Working with our Core Crypto team to expand and improve our suite of crypto products, including deposits, withdrawals, and staking, making them more accessible for our retail users'}, {'name': 'User Experience Design', 'reference_text': 'Working closely with Design and UX Research to define the customer journey and create an amazing user experience'}, {'name': 'Engineering Collaboration', 'reference_text': 'Liaising with Engineering to ensure effective delivery of the product'}, {'name': 'Stakeholder Collaboration', 'reference_text': 'Collaborating with other stakeholders, such as Product Marketing, Legal, and Product Strategy'}, {'name': 'Crypto Exchange Development', 'reference_text': '2-3 years of experience building a crypto exchange platform'}, {'name': 'Trading Product Development', 'reference_text': '2+ years of proven success building the core functionality of trading products'}, {'name': 'People Management', 'reference_text': '1+ years of experience in managing people (Product Owners at Revolut directly manage Engineering, Operations, and Design)'}, {'name': 'Product Management', 'reference_text': 'Experience managing a team of product owners and delivering successful products from 0-1'}, {'name': 'STEM Background', 'reference_text': 'A STEM background'}, {'name': 'Communication Skills', 'reference_text': 'Outstanding verbal and written communication skills'}, {'name': 'UX/UI Design', 'reference_text': 'An eye for great UX/UI and a good understanding of design best practices'}, {'name': 'Technical Backend', 'reference_text': 'An understanding of technical backend with integrations and APIs'}, {'name': 'Analytics', 'reference_text': 'High analytical acumen along with strong business sense that guides ROI based prioritisation'}, {'name': 'Product Vision', 'reference_text': 'Experience formulating and driving a focused product vision, owning the narrative with leadership, users, and partners'}, {'name': 'Bias for Action', 'reference_text': 'A bias to action and bootstrapping major projects, never hesitating to roll up your sleeves and be hands on'}, {'name': 'Ambiguity Tolerance', 'reference_text': 'A readiness to provide insight and deliver measurable results for sophisticated products under ambiguous situations in a fast-paced environment'}]}
# {'name': 'Crypto Exchange Product Management', 'reference_text': 'Completely owning and building our Crypto Exchange product, increasing the number of tokens tradable in the application and providing the tools retail users expect from exchanges'}
# {'name': 'Roadmapping', 'reference_text': "Setting your team's goals, success metrics, and roadmap to align with Revolut’s mission and drive maximum impact based on data analysis, market research, and company strategy"}
# {'name': 'Crypto Product Development', 'reference_text': 'Working with our Core Crypto team to expand and improve our suite of crypto products, including deposits, withdrawals, and staking, making them more accessible for our retail users'}
# {'name': 'User Experience Design', 'reference_text': 'Working closely with Design and UX Research to define the customer journey and create an amazing user experience'}
# {'name': 'Engineering Collaboration', 'reference_text': 'Liaising with Engineering to ensure effective delivery of the product'}
# {'name': 'Stakeholder Collaboration', 'reference_text': 'Collaborating with other stakeholders, such as Product Marketing, Legal, and Product Strategy'}
# {'name': 'Crypto Exchange Development', 'reference_text': '2-3 years of experience building a crypto exchange platform'}
# {'name': 'Trading Product Development', 'reference_text': '2+ years of proven success building the core functionality of trading products'}
# {'name': 'People Management', 'reference_text': '1+ years of experience in managing people (Product Owners at Revolut directly manage Engineering, Operations, and Design)'}
# {'name': 'Product Management', 'reference_text': 'Experience managing a team of product owners and delivering successful products from 0-1'}
# {'name': 'STEM Background', 'reference_text': 'A STEM background'}
# {'name': 'Communication Skills', 'reference_text': 'Outstanding verbal and written communication skills'}
# {'name': 'UX/UI Design', 'reference_text': 'An eye for great UX/UI and a good understanding of design best practices'}
# {'name': 'Technical Backend', 'reference_text': 'An understanding of technical backend with integrations and APIs'}
# {'name': 'Analytics', 'reference_text': 'High analytical acumen along with strong business sense that guides ROI based prioritisation'}
# {'name': 'Product Vision', 'reference_text': 'Experience formulating and driving a focused product vision, owning the narrative with leadership, users, and partners'}
# {'name': 'Bias for Action', 'reference_text': 'A bias to action and bootstrapping major projects, never hesitating to roll up your sleeves and be hands on'}
# {'name': 'Ambiguity Tolerance', 'reference_text': 'A readiness to provide insight and deliver measurable results for sophisticated products under ambiguous situations in a fast-paced environment'}
#
# Job Index: 1
# About the job
#
#
# ASI Reisen ist eine der führenden Reiseplattformen für nachhaltige Aktiv- & Erlebnisreisen weltweit. Seit 1963 stehen wir als Familienunternehmen für Wertschätzung und Innovation im sanften Tourismus. Trotz unserer bald 60-jährigen Erfahrung leben wir eine dynamische Unternehmenskultur mit Start-up Mentalität. Mit unserem Team von 50 Mitarbeiter:innen im ASI Nest und unseren 300 Guides bieten wir rund 4.500 nachhaltige Abenteuerreisen in 100+ Ländern an. Hiking, Trekking, Bike, Alpine, Kanu und vieles mehr.Hast Du Lust die Zukunft des Reisens zu gestalten? Abseits von Kreuzfahrtschiffen und All-Inklusiv-Bunkern? Nachhaltig und auf Augenhöhe mit der lokalen Community? Dann bewirb Dich bei uns. Wir freuen uns auf Dich!Jährliches Bruttogehalt je nach Berufserfahrung von mindestens EUR 55.468 bis maximal EUR 96.053.Deine Aufgaben im Detail Du bist Endverantwortlich für die technische Performance und Weiterentwicklung unserer Plattformen asi-reisen.de und wedesigntrips.comDu führst das Tech Team bestehend aus ERP/Web Development, UX & Product OwnernDu unterstützt dein Team bei der persönlichen Weiterentwicklung ihrer Fähigkeiten und PerformanceDu verantwortest die kontinuierliche Verbesserung von Prozessen in deinem TeamDu bist das Bindeglied zwischen Geschäftsführung & technischer Weiterentwicklung unserer internen & Web SystemenDu monitorst und optimierst die wichtigsten KPIs deines Teams (Ticket-Anzahl, Sprint-Erreichung)Du stellst sicher dass die Kommunikation zu anderen Teams reibungslos läuft
# Dein Profil Du hast umfangreiche Erfahrungen im Aufbau und in der Skalierung von Online MarketplacesDu hast mindestens 5 Jahre Berufserfahrung als Product Owner oder E-Commerce ManagerDu hast mindestens 5 Jahre Berufserfahrung in der Führung von TeamsDu bist kommunikativer und durchsetzungsstarker Teamplayer mit sicherem AuftretenDu arbeitest bereits jetzt agil und verwendest agile Projektmanagement-Methoden, wie Scrum, Sprints, CanbanDu hast ein sehr gutes Verständnis im Tech Bereich, idealerweise in PHP bzw. Symfony, HTML5, CSS3, JS bzw. VueJS & MySQ, C# und .net Du optimierst Prozesse, für die du verantwortlich bistDu triffst Entscheidungen auf der Basis von DatenDu behältst auch in stressigen Situationen den Überblick und kannst sehr gut priorisierenDu verfolgst eine Hands-on Mentalität und genießt ein dynamisches ArbeitsumfeldDu hörst zu und gibst konstruktives Feedback an dem deine Mitarbeiter:innen wachsenDu verfügst über sehr gute Deutschkenntnisse in Wort und Schrift und verhandlungssichere Englischkenntnisse
# Wir bieten Arbeiten im mehrfach ausgezeichneten ASI Nest oder komplett remoteEin tolles und sympathisches Team mit der gleichen Leidenschaft für das Reisen wie duModerne Unternehmenskultur mit flacher Hierarchie und der Möglichkeit schnell Dinge umzusetzenLeistungsorientierte Entlohnung und ErfolgspartizipationJährliches Budget für die Teilnahme an unseren ReisenRegelmäßige Teamevents am Abend, Budget für Ausflüge und Aktivitäten in kleineren GruppenHöhenverstellbare Tische an jedem ArbeitsplatzDuschen zur Sportausübung auf dem Weg zur/weg von der Arbeit oder in der MittagspauseTischtennis & -fußball sowie Mitarbeiter:innengartenKostenlose Parkplätze direkt am FirmengeländeWöchentlich Yoga, Massagen, Obstkorb
# Suchst Du eine herausfordernde Aufgabe mit Sinn? Werde Teil unseres Teams und gestalte mit uns die Zukunft des Reisemarktes. Abseits von Kreuzfahrtschiffen und All-Inclusive-Clubs, dafür auf Augenhöhe mit Land und Leuten.Sende Deinen Lebenslauf gerne gleich an jobs@asi.at. Wir freuen uns auf Deine Bewerbung!
# {'skills': [{'name': 'Team leadership', 'reference_text': 'Du führst das Tech Team bestehend aus ERP/Web Development, UX & Product Ownern'}, {'name': 'Agile project management', 'reference_text': 'Du arbeitest bereits jetzt agil und verwendest agile Projektmanagement-Methoden, wie Scrum, Sprints, Canban'}, {'name': 'Process optimization', 'reference_text': 'Du optimierst Prozesse, für die du verantwortlich bist'}, {'name': 'Data-driven decision making', 'reference_text': 'Du triffst Entscheidungen auf der Basis von Daten'}, {'name': 'Stress management', 'reference_text': 'Du behältst auch in stressigen Situationen den Überblick und kannst sehr gut priorisieren'}, {'name': 'Communication skills', 'reference_text': 'Du hörst zu und gibst konstruktives Feedback an dem deine Mitarbeiter:innen wachsen'}, {'name': 'Technical skills', 'reference_text': 'Du hast ein sehr gutes Verständnis im Tech Bereich, idealerweise in PHP bzw. Symfony, HTML5, CSS3, JS bzw. VueJS & MySQ, C# und .net'}]}
# {'name': 'Team leadership', 'reference_text': 'Du führst das Tech Team bestehend aus ERP/Web Development, UX & Product Ownern'}
# {'name': 'Agile project management', 'reference_text': 'Du arbeitest bereits jetzt agil und verwendest agile Projektmanagement-Methoden, wie Scrum, Sprints, Canban'}
# {'name': 'Process optimization', 'reference_text': 'Du optimierst Prozesse, für die du verantwortlich bist'}
# {'name': 'Data-driven decision making', 'reference_text': 'Du triffst Entscheidungen auf der Basis von Daten'}
# {'name': 'Stress management', 'reference_text': 'Du behältst auch in stressigen Situationen den Überblick und kannst sehr gut priorisieren'}
# {'name': 'Communication skills', 'reference_text': 'Du hörst zu und gibst konstruktives Feedback an dem deine Mitarbeiter:innen wachsen'}
# {'name': 'Technical skills', 'reference_text': 'Du hast ein sehr gutes Verständnis im Tech Bereich, idealerweise in PHP bzw. Symfony, HTML5, CSS3, JS bzw. VueJS & MySQ, C# und .net'}
#
# Job Index: 2
# About the job
#
#
# Department: ProductEmployment Type: Full TimeLocation:  Kraków, PolandReporting To: Paweł KrajewskiCompensation: zł20,000 - zł25,000 / monthDescriptionAbout the role: Head of Product, VoluumCommerce Media Tech is seeking an experienced and strategic-minded Head of Product to join our dynamic team - Voluum. In this pivotal role, you will play a crucial part in defining and executing our product strategy for Voluum, leading and mentoring a team of product managers to better meet the evolving needs of our customers. It is the highest product role in Voluum.If you are a strategic thinker with a passion for leading product teams and shaping the future of advertising technology, we want to hear from you. Join us at Commerce Media Tech as our Head of Product and help us drive innovation, create value for our customers, and shape the future of digital advertising. Apply now to be part of our exciting journey!This position offers full remote work.About Company:Commerce Media Tech is a leading global provider of advertising technology solutions. Our flagship product, Voluum, is a cutting-edge advertising tracking and management platform trusted by top marketers and agencies worldwide. With a strong commitment to innovation and a customer-centric approach, Commerce Media Tech is at the forefront of the digital advertising industry, empowering businesses to optimize their marketing efforts.In November 2020, Commerce Media Tech was acquired by CentralNic Group (now Team Internet). Team Internet is a global company listed on the London Stock Exchange. Team Internet is an organization and corporation serving millions of web customers around the globe.Key Responsibilities Product Strategy: develop and articulate a clear and compelling product vision and strategy for Voluum, aligning it with Commerce Media Tech's overall direction. Team Leadership: lead, mentor, and inspire a team of product managers, fostering a culture of user-centricity, collaboration, and continuous improvement (currently you would work directly with three PMs, two designers and one researcher). Execution: drive the successful execution of the product roadmap, ensuring the timely delivery of high-quality value for our customers. Market Research: stay abreast of industry trends, competitive landscape, and customer feedback to identify opportunities for product improvements and innovation. Customer Focus: develop a deep understanding of customer needs and pain points, working closely with cross-functional teams to prioritize and deliver solutions that provide exceptional value. Cross-Functional Collaboration: collaborate with engineering, design, marketing, and other departments to ensure alignment and successful product launches. Product Analytics: define and track key product metrics to measure the success of product initiatives and iterate based on data-driven insights.
# Skills, Knowledge and ExpertiseRequirements: Proven Experience: at least 4 years of experience in product management, with a minimum of 1 year in a leadership role (huge plus if it’s within the SaaS or advertising technology industry). Strategic Thinker: strong strategic thinking and problem-solving skills, with a track record of shaping and executing product strategy that drive business growth. Team Leadership: demonstrated ability to lead, coach, and develop high-performing product teams. Customer-Centric: a deep commitment to understanding customer needs and delivering exceptional user experiences. Excellent Communication: exceptional communication skills, both written and verbal, with the ability to influence and inspire cross-functional teams. Doing what it takes: not being afraid to work side-by-side with Product Managers and their team to help them improve critical pieces of process or software.
# Nice to Have: Experience in Advertising Technology: familiarity with the digital advertising ecosystem, ad tracking, and campaign optimization tools.
# Benefits Understanding of performance marketing and affiliate marketingTotal compensation package comprised of base salary and variable pay (cash bonus and share options)Flexible working hoursTraining budget and pool of training daysOn-line training platform for everyonePrivate healthcareLife insuranceSport cardGame roomBirthday day offNAIS (benefit cafeteria with monthly bonuses)Additional 3 days off
# {'skills': [{'name': 'Product Strategy', 'reference_text': "develop and articulate a clear and compelling product vision and strategy for Voluum, aligning it with Commerce Media Tech's overall direction."}, {'name': 'Team Leadership', 'reference_text': 'lead, mentor, and inspire a team of product managers, fostering a culture of user-centricity, collaboration, and continuous improvement (currently you would work directly with three PMs, two designers and one researcher).'}, {'name': 'Execution', 'reference_text': 'drive the successful execution of the product roadmap, ensuring the timely delivery of high-quality value for our customers.'}, {'name': 'Market Research', 'reference_text': 'stay abreast of industry trends, competitive landscape, and customer feedback to identify opportunities for product improvements and innovation.'}, {'name': 'Customer Focus', 'reference_text': 'develop a deep understanding of customer needs and pain points, working closely with cross-functional teams to prioritize and deliver solutions that provide exceptional value.'}, {'name': 'Cross-Functional Collaboration', 'reference_text': 'collaborate with engineering, design, marketing, and other departments to ensure alignment and successful product launches.'}, {'name': 'Product Analytics', 'reference_text': 'define and track key product metrics to measure the success of product initiatives and iterate based on data-driven insights.'}, {'name': 'Strategic Thinker', 'reference_text': 'strong strategic thinking and problem-solving skills, with a track record of shaping and executing product strategy that drive business growth.'}, {'name': 'Team Leadership', 'reference_text': 'demonstrated ability to lead, coach, and develop high-performing product teams.'}, {'name': 'Customer-Centric', 'reference_text': 'a deep commitment to understanding customer needs and delivering exceptional user experiences.'}, {'name': 'Excellent Communication', 'reference_text': 'exceptional communication skills, both written and verbal, with the ability to influence and inspire cross-functional teams.'}, {'name': 'Doing what it takes', 'reference_text': 'not being afraid to work side-by-side with Product Managers and their team to help them improve critical pieces of process or software.'}, {'name': 'Experience in Advertising Technology', 'reference_text': 'familiarity with the digital advertising ecosystem, ad tracking, and campaign optimization tools.'}]}
# {'name': 'Product Strategy', 'reference_text': "develop and articulate a clear and compelling product vision and strategy for Voluum, aligning it with Commerce Media Tech's overall direction."}
# {'name': 'Team Leadership', 'reference_text': 'lead, mentor, and inspire a team of product managers, fostering a culture of user-centricity, collaboration, and continuous improvement (currently you would work directly with three PMs, two designers and one researcher).'}
# {'name': 'Execution', 'reference_text': 'drive the successful execution of the product roadmap, ensuring the timely delivery of high-quality value for our customers.'}
# {'name': 'Market Research', 'reference_text': 'stay abreast of industry trends, competitive landscape, and customer feedback to identify opportunities for product improvements and innovation.'}
# {'name': 'Customer Focus', 'reference_text': 'develop a deep understanding of customer needs and pain points, working closely with cross-functional teams to prioritize and deliver solutions that provide exceptional value.'}
# {'name': 'Cross-Functional Collaboration', 'reference_text': 'collaborate with engineering, design, marketing, and other departments to ensure alignment and successful product launches.'}
# {'name': 'Product Analytics', 'reference_text': 'define and track key product metrics to measure the success of product initiatives and iterate based on data-driven insights.'}
# {'name': 'Strategic Thinker', 'reference_text': 'strong strategic thinking and problem-solving skills, with a track record of shaping and executing product strategy that drive business growth.'}
# {'name': 'Team Leadership', 'reference_text': 'demonstrated ability to lead, coach, and develop high-performing product teams.'}
# {'name': 'Customer-Centric', 'reference_text': 'a deep commitment to understanding customer needs and delivering exceptional user experiences.'}
# {'name': 'Excellent Communication', 'reference_text': 'exceptional communication skills, both written and verbal, with the ability to influence and inspire cross-functional teams.'}
# {'name': 'Doing what it takes', 'reference_text': 'not being afraid to work side-by-side with Product Managers and their team to help them improve critical pieces of process or software.'}
# {'name': 'Experience in Advertising Technology', 'reference_text': 'familiarity with the digital advertising ecosystem, ad tracking, and campaign optimization tools.'}
#
# Job Index: 3
# About the job
#
#
# DescriptionAbout us:Pragmatic Play is a leading game developer providing player-favourites to the most successful global brands in the iGaming industry.Powering up new possibilities of play through one single API, Pragmatic Play offers a multi-product portfolio of award-winning slots, live casino, bingo, virtual sports, sportsbook and more, available in all major regulated markets, languages and currencies.Driven by a persistence to craft immersive experiences and responsible thrills, Pragmatic Play's global team consistently deliver best-in-class services with a dedication to create games that players love time and time again.Responsibilities: Produce successful Live Casino products for mobile, tablet and desktop and other platforms in Agile environment;Compose detailed and clear written specifications for new products and features;Define and communicate product vision together with teams of Developers, Designers, Testers, Studio team and other stakeholders;Work closely with Business Intelligence;Coordinate game production, setting daily, short-term and long-term goals and ensure game production proceeds according to schedule;Resolve product development issues, prioritizing product features;Support the Marketing, Business development and Account Management departments in their efforts to ensure revenue and customer satisfaction goals are met;Ensure new products and features are evaluated for usability and performance, employing focus group testing when necessary analyses trends in the gaming market and researching the market: products, customers, competitors, trends.
# Requirements: At least 5 years of experience as a Product Owner with software development teams;Understanding of software development process;Excellent analytical skills;Ability to work with both established and newly formed teams, challenging and supporting them to continuously improve;Good remote work skills;Good record of driving and creating the product concepts and building outstanding solid solutions together with your teams;Able to work in fast moving, high pressure environment while maintaining accuracy and attention to detail;Excellent communication and interpersonal skills;Degree level or higher education;Fluent in English.
# Other attributes we welcome: Experience in game development and /or online gaming;Previous experience in game design;Have a knowledge of casino games and game mathematics;Experience with online casino game marketing and promotions;Knowledge of regulatory compliance for gambling products.
# {'skills': [{'name': 'Live Casino product development', 'reference_text': 'Produce successful Live Casino products for mobile, tablet and desktop and other platforms in Agile environment;'}, {'name': 'Game design and development', 'reference_text': 'Compose detailed and clear written specifications for new products and features;'}, {'name': 'Product management', 'reference_text': 'Define and communicate product vision together with teams of Developers, Designers, Testers, Studio team and other stakeholders;'}, {'name': 'Project management', 'reference_text': 'Coordinate game production, setting daily, short-term and long-term goals and ensure game production proceeds according to schedule;'}, {'name': 'Product testing', 'reference_text': 'Ensure new products and features are evaluated for usability and performance, employing focus group testing when necessary analyses trends in the gaming market and researching the market: products, customers, competitors, trends.'}]}
# {'name': 'Live Casino product development', 'reference_text': 'Produce successful Live Casino products for mobile, tablet and desktop and other platforms in Agile environment;'}
# {'name': 'Game design and development', 'reference_text': 'Compose detailed and clear written specifications for new products and features;'}
# {'name': 'Product management', 'reference_text': 'Define and communicate product vision together with teams of Developers, Designers, Testers, Studio team and other stakeholders;'}
# {'name': 'Project management', 'reference_text': 'Coordinate game production, setting daily, short-term and long-term goals and ensure game production proceeds according to schedule;'}
# {'name': 'Product testing', 'reference_text': 'Ensure new products and features are evaluated for usability and performance, employing focus group testing when necessary analyses trends in the gaming market and researching the market: products, customers, competitors, trends.'}
#
# Job Index: 4
# About the job
#
#
# Proyecto ambicioso|Start up en pleno crecimiento
# About Our ClientStart up con producto innovador en el mercado relacionado con los medios de comunicaciónJob Description  Analisiis y mejora del producto con un claro foco en el consumidor Diseñar ideas para aumentar ventas Transformar las necesidades de negocio en realidades y trasmitirlas al equipo tecnológicoInnovación en la visión y objetivo de la empresa Ideación y conceptualización de proyectos compatibles con el departamento IT.
# The Successful Applicant Mínimo 4 años como CPOExperiencia B2CConocimiento 360 del ciclo de producto
# What's On OfferSalarioRemoto 100%Posibilidad de stock optionsContact: Marian RomeroQuote job ref: JN-102023-6226387
# {'skills': [{'name': 'Product analysis and improvement', 'reference_text': 'Analisiis y mejora del producto con un claro foco en el consumidor'}, {'name': 'Sales strategy', 'reference_text': 'Diseñar ideas para aumentar ventas'}, {'name': 'Transforming business needs into realities', 'reference_text': 'Transformar las necesidades de negocio en realidades y trasmitirlas al equipo tecnológico'}, {'name': 'Innovating company vision and goals', 'reference_text': 'Innovación en la visión y objetivo de la empresa'}, {'name': 'Ideation and conceptualization', 'reference_text': 'Ideación y conceptualización de proyectos compatibles con el departamento IT.'}]}
# {'name': 'Product analysis and improvement', 'reference_text': 'Analisiis y mejora del producto con un claro foco en el consumidor'}
# {'name': 'Sales strategy', 'reference_text': 'Diseñar ideas para aumentar ventas'}
# {'name': 'Transforming business needs into realities', 'reference_text': 'Transformar las necesidades de negocio en realidades y trasmitirlas al equipo tecnológico'}
# {'name': 'Innovating company vision and goals', 'reference_text': 'Innovación en la visión y objetivo de la empresa'}
# {'name': 'Ideation and conceptualization', 'reference_text': 'Ideación y conceptualización de proyectos compatibles con el departamento IT.'}
#
# Job Index: 5
# About the job
#
#
# About our Client :Our client is a German Software Company. They are a team of developers, digitalization experts and data nerds from all over Europe who develop complex software projects.They are now looking for a Head of Product (f/d/m) to work at the intersection of product, marketing, and sales to drive one of their most successful products forward. The Head of Product (f/d/m) will lead a team of currently 6 employees across product and requirements management, marketing, and sales and will work closely with their founder and Managing Director. Further healthy growth of the team is planned for 2024.Your Role: Define and drive the product strategy in close partnership with the founder / CTO and the product, marketing, and sales teams.With your understanding of software development, you create a concise, effective, authentic product message that ensures a unique product positioning.Deriving an ambitious but also realistic product roadmap, which you actively pursue, implement and monitor using jointly defined KPIs.Responsible for effective marketing campaigns, you use market analyses, UX tests and the evaluation of customer feedback to improve the product continuously.Involved in new business processes with national and international clients.
# Who you are:  You have in-depth experience shipping products that users love. You are an excellent communicator: able to rally a team around a goal, and effectively drive decisions where people might disagree.You are comfortable using qualitative data (e.g. user feedback) and quantitative data (e.g. metrics, analytics) to make decisions.You are motivated to grow and operate with autonomy in an often-unpredictable, tech environment.You have management experience but are still hands-on. You are a passionate product nerd with an exceptional understanding of technology — you develop what the customer really needs — and not what they think they need.You stand for unconventional approaches and excellence — with a fresh mindset and great communication skills.
# Specifications:  10+ years of product management experience and demonstrated ability in a product manager role.An entrepreneurial / self-starter mindset who first and foremost knows how to get work done.Deep analytical, prioritization, and problem-solving skills.Excellent knowledge of software development lifecycles, processes, and methodologies. Clear and compelling in written and spoken communication in German and in English (business fluent).
# What our client offers:  100% remote work possible and flexible working time model.A diverse team of experts and a lot of creative freedom in a responsible role.A competitive salary with profit sharing.A company car is possible if desired.Continuous salary increases depending on success.
# If you feel inspired and would like to take on a new challenge with our client, please feel free to apply for this job.#headofproduct #product #leadership #marketing #sales
# {'skills': [{'name': 'Product Management', 'reference_text': 'Define and drive the product strategy in close partnership with the founder / CTO and the product, marketing, and sales teams.'}, {'name': 'Marketing', 'reference_text': 'Responsible for effective marketing campaigns, you use market analyses, UX tests and the evaluation of customer feedback to improve the product continuously.'}, {'name': 'Communication', 'reference_text': 'You are an excellent communicator: able to rally a team around a goal, and effectively drive decisions where people might disagree.'}, {'name': 'Data Analysis', 'reference_text': 'You are comfortable using qualitative data (e.g. user feedback) and quantitative data (e.g. metrics, analytics) to make decisions.'}, {'name': 'Leadership', 'reference_text': 'You have management experience but are still hands-on.'}, {'name': 'Technology', 'reference_text': 'You are a passionate product nerd with an exceptional understanding of technology — you develop what the customer really needs — and not what they think they need.'}]}
# {'name': 'Product Management', 'reference_text': 'Define and drive the product strategy in close partnership with the founder / CTO and the product, marketing, and sales teams.'}
# {'name': 'Marketing', 'reference_text': 'Responsible for effective marketing campaigns, you use market analyses, UX tests and the evaluation of customer feedback to improve the product continuously.'}
# {'name': 'Communication', 'reference_text': 'You are an excellent communicator: able to rally a team around a goal, and effectively drive decisions where people might disagree.'}
# {'name': 'Data Analysis', 'reference_text': 'You are comfortable using qualitative data (e.g. user feedback) and quantitative data (e.g. metrics, analytics) to make decisions.'}
# {'name': 'Leadership', 'reference_text': 'You have management experience but are still hands-on.'}
# {'name': 'Technology', 'reference_text': 'You are a passionate product nerd with an exceptional understanding of technology — you develop what the customer really needs — and not what they think they need.'}
#
# Job Index: 6
# About the job
#
#
# IntroductionStill haven’t found your dream job? Join team Huuuge!!Huuuge Games is a gaming company on a mission to build the world’s largest real-time casual gaming platform connecting millions of players so that they can have fun, socialize & play awesome games.Join Team Huuuge and become a part of an exciting adventure bringing pure fun & truly social experience to millions of players across the universe.As the Head of Slots Product, you will be at the forefront of crafting immersive gameplay experiences for our social casino slots. You will lead a team of passionate game designers, collaborating with artists, developers, and business stakeholders to create slots that captivate players and drive engagement.Responsibilities: Lead a team of game designers (math, audio, art, producers) to develop compelling gameplay mechanics, features, and systems for our social casino slots.Drive the conceptualization and design of game mechanics, user interfaces, levels, and progression systems to ensure an enjoyable and rewarding player experience.Collaborate with cross-functional teams, including artists, programmers, and producers, to bring game concepts to life.Participate in brainstorming sessions and contribute innovative ideas to enhance game features, monetization strategies, and player engagement.Analyze player feedback, metrics, and industry trends to iterate on game design, optimizing gameplay mechanics and features.Maintain a deep understanding of the social casino games market and competitors, identifying opportunities for differentiation and innovation.Take ownership of the game production process from concept to delivery, ensuring timely execution and adherence to project timelines.Possess excellent market and product knowledge with a deep understanding of our products and player base to tailor game development accordingly.Contribute to the continuous improvement of the game development process and adopt Agile/Scrum methodologies.
# Requirements: 3+ years of experience in game design, with a demonstrated track record of contributing to successful online social casino games with slot preferenceProven experience in leading a team of game designers, providing mentorship and fostering a collaborative environment.Understanding of player psychology, engagement strategies, and monetization mechanics within the social casino games industry.Excellent communication skills to effectively collaborate with cross-functional teams and present design concepts.A passion for gaming, staying up-to-date with industry trends, and a desire to push the boundaries of game designAn appreciation for mathematics and art and how they both influence game design.An impressive portfolio of slot games they taken to market with a large audience.A passion for casino and slot games, coupled with a keen eye for innovative gameplay mechanics.Familiarity with Agile/Scrum methodologies is a plus, though not essential.
# {'skills': [{'name': 'Game design', 'reference_text': 'Lead a team of game designers (math, audio, art, producers) to develop compelling gameplay mechanics, features, and systems for our social casino slots.'}, {'name': 'Team leadership', 'reference_text': 'Lead a team of game designers (math, audio, art, producers) to develop compelling gameplay mechanics, features, and systems for our social casino slots.'}, {'name': 'Collaboration', 'reference_text': 'Collaborate with cross-functional teams, including artists, programmers, and producers, to bring game concepts to life.'}, {'name': 'Innovation', 'reference_text': 'Participate in brainstorming sessions and contribute innovative ideas to enhance game features, monetization strategies, and player engagement.'}, {'name': 'Data analysis', 'reference_text': 'Analyze player feedback, metrics, and industry trends to iterate on game design, optimizing gameplay mechanics and features.'}, {'name': 'Market knowledge', 'reference_text': 'Maintain a deep understanding of the social casino games market and competitors, identifying opportunities for differentiation and innovation.'}, {'name': 'Project management', 'reference_text': 'Take ownership of the game production process from concept to delivery, ensuring timely execution and adherence to project timelines.'}, {'name': 'Product knowledge', 'reference_text': 'Possess excellent market and product knowledge with a deep understanding of our products and player base to tailor game development accordingly.'}, {'name': 'Process improvement', 'reference_text': 'Contribute to the continuous improvement of the game development process and adopt Agile/Scrum methodologies.'}, {'name': 'Slot game design experience', 'reference_text': '3+ years of experience in game design, with a demonstrated track record of contributing to successful online social casino games with slot preference'}, {'name': 'Team leadership experience', 'reference_text': 'Proven experience in leading a team of game designers, providing mentorship and fostering a collaborative environment.'}, {'name': 'Social casino game knowledge', 'reference_text': 'Understanding of player psychology, engagement strategies, and monetization mechanics within the social casino games industry.'}, {'name': 'Communication skills', 'reference_text': 'Excellent communication skills to effectively collaborate with cross-functional teams and present design concepts.'}, {'name': 'Passion for gaming', 'reference_text': 'A passion for gaming, staying up-to-date with industry trends, and a desire to push the boundaries of game design'}, {'name': 'Mathematics and art appreciation', 'reference_text': 'An appreciation for mathematics and art and how they both influence game design.'}, {'name': 'Portfolio of launched games', 'reference_text': 'An impressive portfolio of slot games they taken to market with a large audience.'}, {'name': 'Passion for casino games', 'reference_text': 'A passion for casino and slot games, coupled with a keen eye for innovative gameplay mechanics.'}, {'name': 'Agile/Scrum knowledge', 'reference_text': 'Familiarity with Agile/Scrum methodologies is a plus, though not essential.'}]}
# {'name': 'Game design', 'reference_text': 'Lead a team of game designers (math, audio, art, producers) to develop compelling gameplay mechanics, features, and systems for our social casino slots.'}
# {'name': 'Team leadership', 'reference_text': 'Lead a team of game designers (math, audio, art, producers) to develop compelling gameplay mechanics, features, and systems for our social casino slots.'}
# {'name': 'Collaboration', 'reference_text': 'Collaborate with cross-functional teams, including artists, programmers, and producers, to bring game concepts to life.'}
# {'name': 'Innovation', 'reference_text': 'Participate in brainstorming sessions and contribute innovative ideas to enhance game features, monetization strategies, and player engagement.'}
# {'name': 'Data analysis', 'reference_text': 'Analyze player feedback, metrics, and industry trends to iterate on game design, optimizing gameplay mechanics and features.'}
# {'name': 'Market knowledge', 'reference_text': 'Maintain a deep understanding of the social casino games market and competitors, identifying opportunities for differentiation and innovation.'}
# {'name': 'Project management', 'reference_text': 'Take ownership of the game production process from concept to delivery, ensuring timely execution and adherence to project timelines.'}
# {'name': 'Product knowledge', 'reference_text': 'Possess excellent market and product knowledge with a deep understanding of our products and player base to tailor game development accordingly.'}
# {'name': 'Process improvement', 'reference_text': 'Contribute to the continuous improvement of the game development process and adopt Agile/Scrum methodologies.'}
# {'name': 'Slot game design experience', 'reference_text': '3+ years of experience in game design, with a demonstrated track record of contributing to successful online social casino games with slot preference'}
# {'name': 'Team leadership experience', 'reference_text': 'Proven experience in leading a team of game designers, providing mentorship and fostering a collaborative environment.'}
# {'name': 'Social casino game knowledge', 'reference_text': 'Understanding of player psychology, engagement strategies, and monetization mechanics within the social casino games industry.'}
# {'name': 'Communication skills', 'reference_text': 'Excellent communication skills to effectively collaborate with cross-functional teams and present design concepts.'}
# {'name': 'Passion for gaming', 'reference_text': 'A passion for gaming, staying up-to-date with industry trends, and a desire to push the boundaries of game design'}
# {'name': 'Mathematics and art appreciation', 'reference_text': 'An appreciation for mathematics and art and how they both influence game design.'}
# {'name': 'Portfolio of launched games', 'reference_text': 'An impressive portfolio of slot games they taken to market with a large audience.'}
# {'name': 'Passion for casino games', 'reference_text': 'A passion for casino and slot games, coupled with a keen eye for innovative gameplay mechanics.'}
# {'name': 'Agile/Scrum knowledge', 'reference_text': 'Familiarity with Agile/Scrum methodologies is a plus, though not essential.'}
#
# Job Index: 7
# About the job
#
#
# Über Tele Columbus AGWir sind einer der führenden Glasfasernetzbetreiber in Deutschland mit mehr als drei Millionen angeschlossenen Haushalten. Unter unserer Marke bieten wir Highspeed-Internet, Telefon und klassisches Fernsehen an. Als Partner der Wohnungswirtschaft sind wir regional verwurzelt und treiben den glasfaserbasierten Infrastruktur- und Breitbandausbau in Deutschland maßgeblich voran.Wir suchen zum nächstmöglichen Zeitpunkt für unsere Standorte Berlin, Leipzig oder remote (in Deutschland) Verstärkung für unser Team eine:n Senior Product Owner (all genders)Was erwartet dich? Vorantreiben des Anforderungs- und Stakeholdermanagements für die zu verantworteten SoftwarekomponentenAnalyse der Business Anforderungen sowie Erkennen und Definieren der daraus resultierenden technischen ProduktanforderungenKommunikation der Stakeholderanforderungen an die Product-TeamsPriorisierung der Anforderungen in Abstimmung mit anderen POs anhand der UnternehmensprioritätetenErstellung von Epics und Stories in enger Zusammenarbeit mit dem Product-Team, den Architekt:innen und Stakeholder:innenKommunikation der zeitlichen Implikationen auf die Unternehmensroadmap an Management und Stakeholder:innenTreiben der Agilisierung mit fundierten Fachwissen und Fähigkeiten; Sichtbarmachen von Fortschritten und Projekterfolgen anhand von KPIs und ROI
# Was solltest du mitbringen? Abgeschlossenes Studium der Wirtschaftsinformatik / Informatik oder vergleichsbare Berufsausbildung oder relevante Erfahrung im agilen Projektmanagement für SoftwareentwicklungZertifizierter Scrum Product Owner mit relevanter Erfahrung im Arbeiten im agilen Set UpTiefgreifende Kenntnisse des Scaled Agile Frameworks sowie Erfahrung mit der Leitung mehrerer Product TeamsSehr gute Kenntnisse von Jira und Confluence oder ähnlichen ToolsVerhandlungssichere Deutsch und Englisch Kenntnisse
# ...
# {'name': 'scaling engineering teams', 'reference_text': 'Experience building and scaling high achieving engineering teams'}
# {'name': 'communication and collaboration', 'reference_text': 'Excellent communication and collaboration skills to partner closely with Product Owners and Business Heads'}
#
# Job Index: 23
# About the job
#
#
# Hi there!This is our role Product Owner for those who know how to build a successful product development strategy, appreciate communication with users, and are ready to conquer the international market together with the team.Tasks in the role Define the product’s vision, strategy, and roadmap by ensuring that the product supports the company’s overall strategy and goals. Translating product strategy into detailed requirements and prototypes.Creating a product roadmap for the long term (1-2 years).Formation of product hypotheses, their defense, and verification.Identification, elaboration, and prioritization of requirements from stakeholders.Gain a deep understanding of internal customer experience, identify and fill product gaps, and generate new ideas to improve the internal customer experience.Scope and prioritize the product backlog based on business and customer impact.Definition, monitoring, and analysis of product metrics.Interact with data providers and development teams.Conduct product planning and PBR with the development team. Drive product launches, including working with all relevant stakeholders.Protection and regular synchronization of product strategy with business representatives.Communication of product plans to the company’s employees. Act as a product evangelist to build awareness and understanding of your product area.
# Who we are looking for Experience in a Product Owner or Product Manager role.High-level knowledge of product analytics (and experience in applying it).Experience in solving problems related to public API management and API Gateways.Experience in managing multiple stakeholders and driving company-wide initiatives.Experience in setting objectives for the engineering teams.Ability to listen and hear the other party, to negotiate and build win-win solutions.Excellent communication and presentation skills.Analytical mindset, work experience, and/or desire to work with such a mindset.You have experience working on requirements for public APIs and engineering problems related to public APIs.Experience working on products for connecting internal engineering teams with customer engineers.Engineering background.English proficiency to at least an upper-intermediate level.
# They say there are no perfect candidates, but that might well be you, ifYou share our common values:understanding Trust, as we prefer to speak up and be our true selves; Sense of Ownership, as it’s not worth wasting time on something you don’t believe in; and enthusiasm for Constant Changes, as we are always looking to make things better.A Bit About The TeamThe Iris Team is responsible for the development of API Gateway, the point of integration of all company public APIs. This team oversees the integration of every Semrush product API into the public SDK used by customers and partners to get Semrush data.As the team responsible for API Gateway, the focus is on everything we do to ensure API is secure, available, and robust. This includes the actions people must take, the processes they must follow, and the technology that supports them throughout the API life cycle.We will try to create all the right conditions for you to work and rest comfortably  It’s up to you to decide what work format works best for you. You can #wfo, #wfh, or mix both.Flexible working day start.Psychologist consultations.Breakfast, snacks, and coffee at the office.Corporate events.Multi-sport card and compensation for hobby expense (Employee+Family).Unlimited PTO.Hobby benefit.Training, courses, conferences.English and Czech courses.Gifts for employees.
# Finally, a Little More About Our CompanyWe’ve been developing our product for 15 years and have been awarded G2's Top 100 Software Products, Global and US Search Awards 2021, Great Place to Work Certification, Deloitte Technology Fast 500 and many more. In March 2021 Semrush went public and started trading on the NYSE with the SEMR ticker.10,000,000+ users in America, Europe, Asia, and Australia have already tried Semrush, and over 1,000 people around the world are working on its development. The Semrush team is constantly growing.Semrush is an equal opportunity employer. We celebrate diversity and are committed to creating an inclusive environment for all employees. We do not discriminate based upon race, religion, creed, color, national origin, sex, pregnancy, sexual orientation, gender identity, gender expression, age, ancestry, physical or mental disability, or medical condition including medical characteristics, genetic identity, marital status, military service, or any other classification protected by applicable local, state or federal laws. All employment decisions are based on business needs, job requirements, merit, and individual qualifications.NataliaResearchernatalia.shmareva@semrush.com
# {'skills': [{'name': 'Product strategy', 'reference_text': 'Define the product’s vision, strategy, and roadmap by ensuring that the product supports the company’s overall strategy and goals.'}, {'name': 'Requirements analysis', 'reference_text': 'Translating product strategy into detailed requirements and prototypes.Creating a product roadmap for the long term (1-2 years).Formation of product hypotheses, their defense, and verification.Identification, elaboration, and prioritization of requirements from stakeholders.'}, {'name': 'Product management', 'reference_text': 'Scope and prioritize the product backlog based on business and customer impact.Definition, monitoring, and analysis of product metrics.Interact with data providers and development teams.Conduct product planning and PBR with the development team. Drive product launches, including working with all relevant stakeholders.'}, {'name': 'Analytics', 'reference_text': 'High-level knowledge of product analytics (and experience in applying it).'}, {'name': 'API management', 'reference_text': 'Experience in solving problems related to public API management and API Gateways.'}, {'name': 'Stakeholder management', 'reference_text': 'Experience in managing multiple stakeholders and driving company-wide initiatives.'}, {'name': 'Team leadership', 'reference_text': 'Experience in setting objectives for the engineering teams.'}, {'name': 'Communication', 'reference_text': 'Excellent communication and presentation skills.'}, {'name': 'Analytical thinking', 'reference_text': 'Analytical mindset, work experience, and/or desire to work with such a mindset.'}, {'name': 'API development', 'reference_text': 'You have experience working on requirements for public APIs and engineering problems related to public APIs.'}, {'name': 'Internal tools', 'reference_text': 'Experience working on products for connecting internal engineering teams with customer engineers.'}, {'name': 'Engineering', 'reference_text': 'Engineering background.'}]}
# {'name': 'Product strategy', 'reference_text': 'Define the product’s vision, strategy, and roadmap by ensuring that the product supports the company’s overall strategy and goals.'}
# {'name': 'Requirements analysis', 'reference_text': 'Translating product strategy into detailed requirements and prototypes.Creating a product roadmap for the long term (1-2 years).Formation of product hypotheses, their defense, and verification.Identification, elaboration, and prioritization of requirements from stakeholders.'}
# {'name': 'Product management', 'reference_text': 'Scope and prioritize the product backlog based on business and customer impact.Definition, monitoring, and analysis of product metrics.Interact with data providers and development teams.Conduct product planning and PBR with the development team. Drive product launches, including working with all relevant stakeholders.'}
# {'name': 'Analytics', 'reference_text': 'High-level knowledge of product analytics (and experience in applying it).'}
# {'name': 'API management', 'reference_text': 'Experience in solving problems related to public API management and API Gateways.'}
# {'name': 'Stakeholder management', 'reference_text': 'Experience in managing multiple stakeholders and driving company-wide initiatives.'}
# {'name': 'Team leadership', 'reference_text': 'Experience in setting objectives for the engineering teams.'}
# {'name': 'Communication', 'reference_text': 'Excellent communication and presentation skills.'}
# {'name': 'Analytical thinking', 'reference_text': 'Analytical mindset, work experience, and/or desire to work with such a mindset.'}
# {'name': 'API development', 'reference_text': 'You have experience working on requirements for public APIs and engineering problems related to public APIs.'}
# {'name': 'Internal tools', 'reference_text': 'Experience working on products for connecting internal engineering teams with customer engineers.'}
# {'name': 'Engineering', 'reference_text': 'Engineering background.'}
#
# Job Index: 24
# About the job
#
#
# IntroDu bist ein erfahrener IT- und Informationssicherheitsexperte mit einer Leidenschaft für die Erstellung von Inhalten? Du bist bereit, die Rolle eines Content Owners für Informationssicherheit zu übernehmen? Du möchtest die IT- und Informationssicherheitsinhalte für unsere Professional Services-Experten, Kunden und Interessenten gestalten? Wenn du mit Ja geantwortet hast, freuen wir uns von dir zu hören! Bewirb dich jetzt und werde Teil unseres Teams.CompanyWir sind ein schnell wachsendes Technologieunternehmen mit einem klaren Ziel: Wir schützen die Menschen hinter den Daten. Mit über 250 Teammitgliedern weltweit und Niederlassungen in München, Berlin, London und Wien helfen wir mehr als 3.000 internationalen Kunden, durch Datenschutz, Informationssicherheit und Compliance Vertrauen aufzubauen, Risiken zu mindern und den Umsatz zu steigern. Dazu kombinieren wir erstklassigen Expertensupport mit unserer selbst entwickelten SaaS-Plattform, um eine effiziente Komplettlösung anzubieten.Responsibilities Du arbeitest mit funktionsübergreifenden Teams zusammen, um Inhalte und Lösungen für unseren einzigartigen hybriden Ansatz - Experten + SaaS-Lösung - zu entwickelnDeine Rolle umfasst die Recherche (50 %), die Bereitstellung (40 %) sowie die Veröffentlichung und Monitoring (10 %)Du arbeitest eng mit unseren Datenschutz- und InfoSec-Experten zusammen, um die Einhaltung der PIC-Standards zu gewährleistenDu treibst die Entwicklung von Informationssicherheitslösungen voran und gibst Stakeholdern eine Richtung vorDu tauschst dich aktiv mit unserem Lead Product Content zur Verbesserung der Inhalte und Optimierung der Produktnutzung ausDu übernimmst Verantwortung für den Product Lifecycle und schlägst eine Brücke zwischen Kunden und Teams, um aktiv für unsere Inhalte und Produkte werben
# Benefits Die Freiheit, das Vertrauen und die Tools, die du benötigst, um in einem stark werteorientierten Unternehmen das zu tun, was du liebstEin attraktives Gehalt, flexible und auf deine Bedürfnisse angepasste Arbeitszeiten und Benefits für Gesundheit, Familie und NachhaltigkeitEin zukunftssicherer Job mit professioneller Arbeitsatmosphäre und der Dynamik eines rasant wachsenden Scale-upsDie Möglichkeit, dich in eine Mentoren-Rolle weiterzuentwickeln und junge Talente zu fördern
# Profile  Mehr als 3 Jahre Erfahrung in ISO 9001, ISO 27001, NIS-2, BSI Grundschutz, B3S, SOC2 und TISAX®️, mit einem starken Fokus auf die Entwicklung von Informationssicherheits-Managementsystemen (ISMS) gemäß ISO270012+ Jahre Erfahrung im B2B SaaSAußergewöhnliche Multitasking-Fähigkeiten zur Verwaltung verschiedener ProjekteFließend in Deutsch und Englisch in Wort und SchriftKundenzentrierte Denkweise und prozessorientiertes Denken.
# EIN PAAR LETZTE WORTE. EHRLICH UND VON HERZEN.Unabhängig von deiner Herkunft, Ethnie, Geschlechtsidentität, Religion oder deinen individuellen Voraussetzungen: Bei uns zählt das, was hinter dem Menschen steckt. Als Guards und Guardettes verbindet uns neben unserer Hingabe der Glaube an unser gemeinsames Ziel: Protect the people behind the data. Überzeuge uns mit deiner Persönlichkeit und deinen Skills – und wir werden gemeinsam Großes bewegen. Wir freuen uns auf dich!
# {'skills': [{'name': 'ISO 9001', 'reference_text': 'Mehr als 3 Jahre Erfahrung in ISO 9001, ISO 27001, NIS-2, BSI Grundschutz, B3S, SOC2 und TISAX®️, mit einem starken Fokus auf die Entwicklung von Informationssicherheits-Managementsystemen (ISMS) gemäß ISO27001'}, {'name': 'ISO 27001', 'reference_text': 'Mehr als 3 Jahre Erfahrung in ISO 9001, ISO 27001, NIS-2, BSI Grundschutz, B3S, SOC2 und TISAX®️, mit einem starken Fokus auf die Entwicklung von Informationssicherheits-Managementsystemen (ISMS) gemäß ISO27001'}, {'name': 'NIS-2', 'reference_text': 'Mehr als 3 Jahre Erfahrung in ISO 9001, ISO 27001, NIS-2, BSI Grundschutz, B3S, SOC2 und TISAX®️, mit einem starken Fokus auf die Entwicklung von Informationssicherheits-Managementsystemen (ISMS) gemäß ISO27001'}, {'name': 'BSI Grundschutz', 'reference_text': 'Mehr als 3 Jahre Erfahrung in ISO 9001, ISO 27001, NIS-2, BSI Grundschutz, B3S, SOC2 und TISAX®️, mit einem starken Fokus auf die Entwicklung von Informationssicherheits-Managementsystemen (ISMS) gemäß ISO27001'}, {'name': 'B3S', 'reference_text': 'Mehr als 3 Jahre Erfahrung in ISO 9001, ISO 27001, NIS-2, BSI Grundschutz, B3S, SOC2 und TISAX®️, mit einem starken Fokus auf die Entwicklung von Informationssicherheits-Managementsystemen (ISMS) gemäß ISO27001'}, {'name': 'SOC2', 'reference_text': 'Mehr als 3 Jahre Erfahrung in ISO 9001, ISO 27001, NIS-2, BSI Grundschutz, B3S, SOC2 und TISAX®️, mit einem starken Fokus auf die Entwicklung von Informationssicherheits-Managementsystemen (ISMS) gemäß ISO27001'}, {'name': 'TISAX', 'reference_text': 'Mehr als 3 Jahre Erfahrung in ISO 9001, ISO 27001, NIS-2, BSI Grundschutz, B3S, SOC2 und TISAX®️, mit einem starken Fokus auf die Entwicklung von Informationssicherheits-Managementsystemen (ISMS) gemäß ISO27001'}]}
# {'name': 'ISO 9001', 'reference_text': 'Mehr als 3 Jahre Erfahrung in ISO 9001, ISO 27001, NIS-2, BSI Grundschutz, B3S, SOC2 und TISAX®️, mit einem starken Fokus auf die Entwicklung von Informationssicherheits-Managementsystemen (ISMS) gemäß ISO27001'}
# {'name': 'ISO 27001', 'reference_text': 'Mehr als 3 Jahre Erfahrung in ISO 9001, ISO 27001, NIS-2, BSI Grundschutz, B3S, SOC2 und TISAX®️, mit einem starken Fokus auf die Entwicklung von Informationssicherheits-Managementsystemen (ISMS) gemäß ISO27001'}
# {'name': 'NIS-2', 'reference_text': 'Mehr als 3 Jahre Erfahrung in ISO 9001, ISO 27001, NIS-2, BSI Grundschutz, B3S, SOC2 und TISAX®️, mit einem starken Fokus auf die Entwicklung von Informationssicherheits-Managementsystemen (ISMS) gemäß ISO27001'}
# {'name': 'BSI Grundschutz', 'reference_text': 'Mehr als 3 Jahre Erfahrung in ISO 9001, ISO 27001, NIS-2, BSI Grundschutz, B3S, SOC2 und TISAX®️, mit einem starken Fokus auf die Entwicklung von Informationssicherheits-Managementsystemen (ISMS) gemäß ISO27001'}
# {'name': 'B3S', 'reference_text': 'Mehr als 3 Jahre Erfahrung in ISO 9001, ISO 27001, NIS-2, BSI Grundschutz, B3S, SOC2 und TISAX®️, mit einem starken Fokus auf die Entwicklung von Informationssicherheits-Managementsystemen (ISMS) gemäß ISO27001'}
# {'name': 'SOC2', 'reference_text': 'Mehr als 3 Jahre Erfahrung in ISO 9001, ISO 27001, NIS-2, BSI Grundschutz, B3S, SOC2 und TISAX®️, mit einem starken Fokus auf die Entwicklung von Informationssicherheits-Managementsystemen (ISMS) gemäß ISO27001'}
# {'name': 'TISAX', 'reference_text': 'Mehr als 3 Jahre Erfahrung in ISO 9001, ISO 27001, NIS-2, BSI Grundschutz, B3S, SOC2 und TISAX®️, mit einem starken Fokus auf die Entwicklung von Informationssicherheits-Managementsystemen (ISMS) gemäß ISO27001'}
